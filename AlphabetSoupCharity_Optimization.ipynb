# %% [markdown]
# <a href="https://colab.research.google.com/github/jasonstonemed/deep-learning-challenge/blob/main/AlphabetSoupCharity_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np



#  Import and read the charity_data.csv.
import_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv").sample(n=25000, random_state=42)

# %%
# Make working copy of the dataframe that won't change when running new parameters
application_df = import_df.copy()

application_df.head()
# Out:
#              EIN                                              NAME  \
# 7346   271598055  ASSOCIATION OF ST AUGUSTINE ALUMNI - ATLANTA INC
# 30868  900109768        AMERICAN SOCIETY OF ADDICTION MEDICINE INC
# 10670  352562499                                     TOPS CLUB INC
# 22408  611766879                                     TOPS CLUB INC
# 119     10874048                  INTERNATIONAL RAFTING FEDERATION
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 7346                T3       Independent          C1000  Preservation
# 30868               T3  CompanySponsored          C1000  Preservation
# 10670               T3  CompanySponsored          C1200  Preservation
# 22408               T3  CompanySponsored          C1200  Preservation
# 119                 T4       Independent          C1000    ProductDev
#
#       ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 7346         Trust       1  100000-499999                      N    50087
# 30868        Trust       1              0                      N     5000
# 10670  Association       1              0                      N     5000
# 22408  Association       1              0                      N     5000
# 119          Trust       1              0                      N     5000
#
#        IS_SUCCESSFUL
# 7346               1
# 30868              1
# 10670              0
# 22408              0
# 119                1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(columns= ['EIN', 'NAME', 'STATUS', 'SPECIAL_CONSIDERATIONS'])
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 7346                T3       Independent          C1000  Preservation
# 30868               T3  CompanySponsored          C1000  Preservation
# 10670               T3  CompanySponsored          C1200  Preservation
# 22408               T3  CompanySponsored          C1200  Preservation
# 119                 T4       Independent          C1000    ProductDev
# ...                ...               ...            ...           ...
# 3675                T8  CompanySponsored          C1000  Preservation
# 15450               T3       Independent          C2000  Preservation
# 20608               T3  CompanySponsored          C1000  Preservation
# 17348               T3  CompanySponsored          C2100  Preservation
# 13763               T4       Independent          C2000    ProductDev
#
#       ORGANIZATION     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 7346         Trust  100000-499999    50087              1
# 30868        Trust              0     5000              1
# 10670  Association              0     5000              0
# 22408  Association              0     5000              0
# 119          Trust              0     5000              1
# ...            ...            ...      ...            ...
# 3675         Trust              0     5000              0
# 15450        Trust              0     5000              1
# 20608  Association  100000-499999    19585              0
# 17348        Trust              0     5000              0
# 13763        Trust    25000-99999    55632              0
#
# [25000 rows x 8 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# EIN                       25000
# NAME                      14531
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               61
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    6400
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df.APPLICATION_TYPE.value_counts()
application_counts
# Out:
# T3     19718
# T4      1122
# T6       896
# T5       866
# T19      760
# T8       531
# T7       515
# T10      389
# T9       113
# T13       47
# T12       19
# T2        15
# T25        3
# T14        2
# T29        2
# T15        1
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       19718
# T4        1122
# T6         896
# T5         866
# T19        760
# Other      592
# T8         531
# T7         515
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df.CLASSIFICATION.value_counts()
classification_counts
# Out:
# C1000    12671
# C2000     4404
# C1200     3512
# C3000     1398
# C2100     1357
#          ...
# C8210        1
# C1900        1
# C2190        1
# C2600        1
# C1245        1
# Name: CLASSIFICATION, Length: 61, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# C1000    12671
# C2000     4404
# C1200     3512
# C3000     1398
# C2100     1357
# C7000      569
# C1700      200
# C4000      133
# C1270       92
# C5000       87
# C2700       82
# C2800       71
# C7100       57
# C1300       44
# C1280       33
# C1230       29
# C1400       26
# C7200       25
# C2300       23
# C1240       21
# C8000       16
# C7120       15
# C1500       14
# C6000       13
# C1250       10
# C1235        9
# C8200        9
# C1237        8
# C1800        8
# C1238        8
# C1278        5
# C1257        5
# C4100        5
# C2400        4
# C7210        3
# C1260        3
# C1256        2
# C1246        2
# C1234        2
# C1600        2
# C0           2
# C1720        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    12671
# C2000     4404
# C1200     3512
# Other     1658
# C3000     1398
# C2100     1357
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df
# Out:
#              EIN  STATUS  ASK_AMT  IS_SUCCESSFUL  \
# 7346   271598055       1    50087              1
# 30868  900109768       1     5000              1
# 10670  352562499       1     5000              0
# 22408  611766879       1     5000              0
# 119     10874048       1     5000              1
# ...          ...     ...      ...            ...
# 3675   237214594       1     5000              0
# 15450  462659357       1     5000              1
# 20608  521242195       1    19585              0
# 17348  470985271       1     5000              0
# 13763  454611815       1    55632              0
#
#        NAME_1 DAY RANCH RESCUE AND RURAL OKLAHOMA ANIMAL RESOURCE INC  \
# 7346                                                   0
# 30868                                                  0
# 10670                                                  0
# 22408                                                  0
# 119                                                    0
# ...                                                  ...
# 3675                                                   0
# 15450                                                  0
# 20608                                                  0
# 17348                                                  0
# 13763                                                  0
#
#        NAME_100 BLACK MEN OF MEMPHIS INC  \
# 7346                                   0
# 30868                                  0
# 10670                                  0
# 22408                                  0
# 119                                    0
# ...                                  ...
# 3675                                   0
# 15450                                  0
# 20608                                  0
# 17348                                  0
# 13763                                  0
#
#        NAME_100 BLACK MEN OF WEST GEORGIA INC  \
# 7346                                        0
# 30868                                       0
# 10670                                       0
# 22408                                       0
# 119                                         0
# ...                                       ...
# 3675                                        0
# 15450                                       0
# 20608                                       0
# 17348                                       0
# 13763                                       0
#
#        NAME_13TH BOMB SQUADRON ASSOCIATION  NAME_14TH ARMORED DIVISION  \
# 7346                                     0                           0
# 30868                                    0                           0
# 10670                                    0                           0
# 22408                                    0                           0
# 119                                      0                           0
# ...                                    ...                         ...
# 3675                                     0                           0
# 15450                                    0                           0
# 20608                                    0                           0
# 17348                                    0                           0
# 13763                                    0                           0
#
#        NAME_150TH INTELLIGENCE SQUADRON ENLISTED ADVISORY COUNCIL  ...  \
# 7346                                                   0           ...
# 30868                                                  0           ...
# 10670                                                  0           ...
# 22408                                                  0           ...
# 119                                                    0           ...
# ...                                                  ...           ...
# 3675                                                   0           ...
# 15450                                                  0           ...
# 20608                                                  0           ...
# 17348                                                  0           ...
# 13763                                                  0           ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 7346                   0                       0                         1
# 30868                  0                       0                         0
# 10670                  0                       0                         0
# 22408                  0                       0                         0
# 119                    0                       0                         0
# ...                  ...                     ...                       ...
# 3675                   0                       0                         0
# 15450                  0                       0                         0
# 20608                  0                       0                         1
# 17348                  0                       0                         0
# 13763                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 7346                    0                 0                       0
# 30868                   0                 0                       0
# 10670                   0                 0                       0
# 22408                   0                 0                       0
# 119                     0                 0                       0
# ...                   ...               ...                     ...
# 3675                    0                 0                       0
# 15450                   0                 0                       0
# 20608                   0                 0                       0
# 17348                   0                 0                       0
# 13763                   0                 0                       1
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 7346                 0                  0                         1
# 30868                0                  0                         1
# 10670                0                  0                         1
# 22408                0                  0                         1
# 119                  0                  0                         1
# ...                ...                ...                       ...
# 3675                 0                  0                         1
# 15450                0                  0                         1
# 20608                0                  0                         1
# 17348                0                  0                         1
# 13763                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 7346                          0
# 30868                         0
# 10670                         0
# 22408                         0
# 119                           0
# ...                         ...
# 3675                          0
# 15450                         0
# 20608                         0
# 17348                         0
# 13763                         0
#
# [25000 rows x 14575 columns]

# %%
# Split our preprocessed data into our features and target arrays
y = application_df['IS_SUCCESSFUL'].values
X = application_df.drop(columns=['IS_SUCCESSFUL']).values

# Split the preprocessed data into a training and testing dataset
X_test, X_train, y_test, y_train = train_test_split(X,y, random_state=42)

# %%
# check y array
y[:5]
# Out:
# array([1, 1, 0, 0, 1])

# %%
# Check X array
X[:5]
# Out:
# array([[271598055,         1,     50087, ...,         0,         1,
#                 0],
#        [900109768,         1,      5000, ...,         0,         1,
#                 0],
#        [352562499,         1,      5000, ...,         0,         1,
#                 0],
#        [611766879,         1,      5000, ...,         0,         1,
#                 0],
#        [ 10874048,         1,      5000, ...,         0,         1,
#                 0]])

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
nn = tf.keras.models.Sequential()

# First hidden layer- input layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu", input_dim=14574))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 72875
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 72,911
# Trainable params: 72,911
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=105)
# Out:
# Epoch 1/105
# 196/196 [==============================] - 2s 6ms/step - loss: 0.8869 - accuracy: 0.3554
# Epoch 2/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.5910 - accuracy: 0.5638
# Epoch 3/105
# 196/196 [==============================] - 2s 12ms/step - loss: 0.4106 - accuracy: 0.8507
# Epoch 4/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.2946 - accuracy: 0.9115
# Epoch 5/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1967 - accuracy: 0.9395
# Epoch 6/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1575 - accuracy: 0.9440
# Epoch 7/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1376 - accuracy: 0.9534
# Epoch 8/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.1285 - accuracy: 0.9544
# Epoch 9/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.1236 - accuracy: 0.9542
# Epoch 10/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1189 - accuracy: 0.9563
# Epoch 11/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1161 - accuracy: 0.9574
# Epoch 12/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.1136 - accuracy: 0.9589
# Epoch 13/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1116 - accuracy: 0.9589
# Epoch 14/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.1108 - accuracy: 0.9595
# Epoch 15/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1102 - accuracy: 0.9597
# Epoch 16/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1086 - accuracy: 0.9627
# Epoch 17/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.1074 - accuracy: 0.9621
# Epoch 18/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1063 - accuracy: 0.9634
# Epoch 19/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1059 - accuracy: 0.9638
# Epoch 20/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1054 - accuracy: 0.9619
# Epoch 21/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.1042 - accuracy: 0.9637
# Epoch 22/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.1048 - accuracy: 0.9613
# Epoch 23/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1043 - accuracy: 0.9654
# Epoch 24/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1035 - accuracy: 0.9640
# Epoch 25/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1029 - accuracy: 0.9638
# Epoch 26/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.1023 - accuracy: 0.9653
# Epoch 27/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1029 - accuracy: 0.9642
# Epoch 28/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1019 - accuracy: 0.9645
# Epoch 29/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.1028 - accuracy: 0.9640
# Epoch 30/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.1013 - accuracy: 0.9648
# Epoch 31/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1029 - accuracy: 0.9640
# Epoch 32/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1011 - accuracy: 0.9634
# Epoch 33/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.1016 - accuracy: 0.9640
# Epoch 34/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.1008 - accuracy: 0.9637
# Epoch 35/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0969 - accuracy: 0.9675
# Epoch 36/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0965 - accuracy: 0.9656
# Epoch 37/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0968 - accuracy: 0.9664
# Epoch 38/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0981 - accuracy: 0.9658
# Epoch 39/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0973 - accuracy: 0.9651
# Epoch 40/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0960 - accuracy: 0.9675
# Epoch 41/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0961 - accuracy: 0.9667
# Epoch 42/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0964 - accuracy: 0.9664
# Epoch 43/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0967 - accuracy: 0.9653
# Epoch 44/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0969 - accuracy: 0.9642
# Epoch 45/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0958 - accuracy: 0.9674
# Epoch 46/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0958 - accuracy: 0.9672
# Epoch 47/105
# 196/196 [==============================] - 2s 11ms/step - loss: 0.0963 - accuracy: 0.9672
# Epoch 48/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0959 - accuracy: 0.9678
# Epoch 49/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0958 - accuracy: 0.9662
# Epoch 50/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0957 - accuracy: 0.9659
# Epoch 51/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0947 - accuracy: 0.9667
# Epoch 52/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0950 - accuracy: 0.9670
# Epoch 53/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0959 - accuracy: 0.9651
# Epoch 54/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0961 - accuracy: 0.9670
# Epoch 55/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0951 - accuracy: 0.9662
# Epoch 56/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0946 - accuracy: 0.9685
# Epoch 57/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0943 - accuracy: 0.9669
# Epoch 58/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0950 - accuracy: 0.9666
# Epoch 59/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0944 - accuracy: 0.9662
# Epoch 60/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0939 - accuracy: 0.9670
# Epoch 61/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0941 - accuracy: 0.9674
# Epoch 62/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0935 - accuracy: 0.9670
# Epoch 63/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0940 - accuracy: 0.9677
# Epoch 64/105
# 196/196 [==============================] - 2s 12ms/step - loss: 0.0945 - accuracy: 0.9662
# Epoch 65/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0935 - accuracy: 0.9674
# Epoch 66/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0924 - accuracy: 0.9669
# Epoch 67/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0911 - accuracy: 0.9685
# Epoch 68/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0908 - accuracy: 0.9677
# Epoch 69/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0906 - accuracy: 0.9672
# Epoch 70/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0898 - accuracy: 0.9661
# Epoch 71/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0870 - accuracy: 0.9686
# Epoch 72/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0865 - accuracy: 0.9680
# Epoch 73/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0852 - accuracy: 0.9677
# Epoch 74/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0866 - accuracy: 0.9675
# Epoch 75/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0861 - accuracy: 0.9682
# Epoch 76/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0865 - accuracy: 0.9670
# Epoch 77/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0860 - accuracy: 0.9675
# Epoch 78/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0853 - accuracy: 0.9682
# Epoch 79/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0861 - accuracy: 0.9680
# Epoch 80/105
# 196/196 [==============================] - 2s 11ms/step - loss: 0.0857 - accuracy: 0.9688
# Epoch 81/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0851 - accuracy: 0.9675
# Epoch 82/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0849 - accuracy: 0.9691
# Epoch 83/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0854 - accuracy: 0.9670
# Epoch 84/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0839 - accuracy: 0.9670
# Epoch 85/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0834 - accuracy: 0.9688
# Epoch 86/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0851 - accuracy: 0.9661
# Epoch 87/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0844 - accuracy: 0.9678
# Epoch 88/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0836 - accuracy: 0.9678
# Epoch 89/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0843 - accuracy: 0.9686
# Epoch 90/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0838 - accuracy: 0.9685
# Epoch 91/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0839 - accuracy: 0.9683
# Epoch 92/105
# 196/196 [==============================] - 1s 8ms/step - loss: 0.0835 - accuracy: 0.9680
# Epoch 93/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0833 - accuracy: 0.9690
# Epoch 94/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0836 - accuracy: 0.9664
# Epoch 95/105
# 196/196 [==============================] - 1s 6ms/step - loss: 0.0833 - accuracy: 0.9685
# Epoch 96/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0830 - accuracy: 0.9699
# Epoch 97/105
# 196/196 [==============================] - 2s 10ms/step - loss: 0.0832 - accuracy: 0.9677
# Epoch 98/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0826 - accuracy: 0.9688
# Epoch 99/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0825 - accuracy: 0.9698
# Epoch 100/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0823 - accuracy: 0.9682
# Epoch 101/105
# 196/196 [==============================] - 1s 7ms/step - loss: 0.0827 - accuracy: 0.9688
# Epoch 102/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0817 - accuracy: 0.9702
# Epoch 103/105
# 196/196 [==============================] - 2s 8ms/step - loss: 0.0832 - accuracy: 0.9675
# Epoch 104/105
# 196/196 [==============================] - 2s 9ms/step - loss: 0.0822 - accuracy: 0.9685
# Epoch 105/105
# 196/196 [==============================] - 2s 12ms/step - loss: 0.0822 - accuracy: 0.9690

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 586/586 - 3s - loss: 0.7230 - accuracy: 0.7738 - 3s/epoch - 4ms/step
# Loss: 0.7229840755462646, Accuracy: 0.7737600207328796

# %%
# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
